# %% [markdown]
# Pandas notebook

# %%
import pandas as pan

# %%
fruits = ["mango","apple","banana","orange",]
series = pan.Series(fruits, name = "fruites")
series.iloc[[2,3]]
# Out:
# 2    banana
# 3    orange
# Name: fruites, dtype: object
